# %%
# !pip install yolov10/.
# !pip install -r yolov10/requirements.txt
# !pip install -e yolov10/.
# !pip install huggingface_hub
# Out:
# Processing ./yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731280 sha256=9b5a3e7c1111c9bc8d874c1431ef7c276cf29bc4379aa9e0e42f25a859de3952
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pzckhvaj/wheels/db/89/c8/4870bca472401578d995d13a06463b6ddd1275f3388e322aae
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.58
#     Uninstalling ultralytics-8.2.58:
#       Successfully uninstalled ultralytics-8.2.58
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Return True means using GPU
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# Train YOLOv5n6
# !python yolov5/train.py --imgsz 480 --epochs 300 --batch 30 --patience 30 --name retrained_v5n6 --data drive_data.yaml --weights pretrained_weights/yolov5n6.pt
# Out:
# train: weights=pretrained_weights/yolov5n6.pt, cfg=, data=drive_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=30, imgsz=480, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=retrained_v5n6, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=30, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 16 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-334-g100a423b Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16020MiB)
#
# ...

# %%
# Train Yolov10n
# !yolo task=detect mode=train epochs=300 patience=30 batch=30 plots=True model=pretrained_weights/yolov10n.pt data=drive_data.yaml imgsz=480 name=retrained_v10n
# Out:
# Ultralytics YOLOv8.2.73 🚀 Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16020MiB)
# ...

# %%
# Train YOLOv5n
# !python yolov5/train.py --imgsz 480 --epochs 300 --pateince 30 --name retrained_v5n --data drive_data.yaml --weights pretrained_weights/yolov5n.pt
# Out:
# train: weights=pretrained_weights/yolov5n.pt, cfg=, data=data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=480, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=retrained_v5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 16 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-334-g100a423b Python-3.9.19 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Ti Laptop GPU, 16020MiB)
#
# ...

# %%
# Train Yolov10s (not yet)
# !yolo task=detect mode=train epochs=300 patience=30 plots=True model=pretrained_weights/yolov10s.pt data=drive_data.yaml imgsz=480 name=retrained_v10s
